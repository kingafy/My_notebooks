# %%
class ItemSelector(BaseEstimator, TransformerMixin):

    def __init__(self, key):
        self.key = key

    def fit(self, x, y=None):
        return self

    def transform(self, data_df):
        return data_df[self.key]
    
    def get_feature_names():
       return []

# %%
from __future__ import print_function, division

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.feature_selection import SelectFromModel, f_classif
from sklearn.ensemble import ExtraTreesClassifier
import pandas as pd
import numpy as np
import csv
print(__doc__)

###File Ingestion
training_file = 'D:/Data Science/POC/Email Classification Product/Email_Dump_OEM_and_Spares_cleaned_Masked_v4.csv'
encoding_format = 'cp1252'
id_column = "Case.Number"
text_column = 
date = 
initial_file  = pd.read_csv(training_file,encoding= encoding_format)

if id_column in initial_file.columns.values:
    if date in initial_file.columns.values:
        input_file_sort = initial_file.sort([id_column, date], ascending=[False, False])
        training = input_file_sort.drop_duplicates(subset = id_column, keep ='first', inplace=True)
    else:
        training = input_file_sort.drop_duplicates(subset = id_column,keep ='first', inplace=True)
else: 
    print("Sort Dedup not required as we dont have duplicates")

numpy_array = training.as_matrix()
numpy_array.dtype.names
##X_cat = training[['Subject','Description']]
X_cat = training['Description']
Y_cat = numpy_array[:,3]

####

##categories = ['alt.atheism', 'soc.religion.christian', 'comp.graphics', 'sci.med']
'''
pipe = Pipeline([
    ('feature_selection', SelectFromModel(LinearSVC(penalty="l1",dual=False))),
    ('reduce_dim', PCA()),
    ('classify', LinearSVC())
])
'''
pipe = Pipeline([
    ('selector', ItemSelector(key='Description')),
    ('feature_selection', SelectFromModel(ExtraTreesClassifier())),
    ('classify', LinearSVC())
])




N_FEATURES_OPTIONS = [2, 4, 8]
N_FEATURES_chi = [10, 20, 30]
C_OPTIONS = [1, 10, 100, 1000]
NUMBER_OF_ESTIMATORS_RF = [50, 80, 100]
##penalty param
L1_C1 = [0.01, 0.02, 0.05]
